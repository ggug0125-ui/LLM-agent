# %%
# ??? ???: langchain, langchain-openai, ipywidgets
# ?? ???? ??? ? ?? ???? ??? ???.
# %pip install langchain langchain-openai ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv(Path(r"C:/LLM agent/Aiprojects/.env"))
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY? ?? ?????. Aiprojects/.env ??? ?????.")

model = ChatOpenAI(model="gpt-4o-mini", openai_api_key=api_key)

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="안녕? 나는 임효정이야.")])

# AIMessage(content='안녕하세요, 임효정님! 만나서 반갑습니다. 어떻게 도와드릴까요?', 
# additional_kwargs={'refusal': None}, 
# response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 16, 'total_tokens': 37, 
# 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 
# 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 
# 'system_fingerprint': 'fp_e2f9fd5023', 'id': 'chatcmpl-DVUT55KXBp4MAr8sPA3CjxGHxScSq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 
# id='lc_run--019d998d-282e-74d0-a8d5-43e7d2cb88a0-0', tool_calls=[], invalid_tool_calls=[], 
# usage_metadata={'input_tokens': 16, 'output_tokens': 21, 'total_tokens': 37, 'input_token_details': {'audio': 0, 'cache_read': 0}, 
# 'output_token_details': {'audio': 0, 'reasoning': 0}})
# Out:
# AIMessage(content='안녕하세요, 임효정님! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 17, 'total_tokens': 32, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_6488829609', 'finish_reason': 'stop', 'logprobs': None}, id='run-786c923c-0c8c-43db-8f66-618326be809e-0', usage_metadata={'input_tokens': 17, 'output_tokens': 15, 'total_tokens': 32})

# %%
model.invoke([HumanMessage(content="내 이름이 뭐지?")])  # 현재는 과거의 메세지를 기억하지 못함

# AIMessage(content='죄송하지만, 당신의 이름을 알 수 있는 정보가 없습니다. 이름을 알려주시면 그에 맞춰 대화할 수 있습니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e2f9fd5023', 'id': 'chatcmpl-DVUUx5P2JMA1O813nCT5rOo0ev9E7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d998e-eaae-7710-8546-f3cd6fb0ffc8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 30, 'total_tokens': 43, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
# Out:
# AIMessage(content='죄송하지만, 당신의 이름을 알 수 있는 정보가 없습니다. 이름을 알려주시면 반갑게 불러드릴 수 있습니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_88ed3d0b53', 'finish_reason': 'stop', 'logprobs': None}, id='run-ec6162b8-2b70-4652-88fb-4aa18103d0ce-0', usage_metadata={'input_tokens': 13, 'output_tokens': 30, 'total_tokens': 43})
